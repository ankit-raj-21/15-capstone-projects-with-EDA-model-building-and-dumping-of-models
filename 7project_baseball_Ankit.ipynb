# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#reading the dataset
df=pd.read_csv('baseball.csv')
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#checking shape
df.shape
# Out:
# (30, 17)

# %%
#column names
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
Features=['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
       'ERA', 'CG', 'SHO', 'SV', 'E']

# %%
Target=['W']

# %%
#checking null value
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
#univariate analysis
sns.distplot(df['R'],bins=10,rug=True)

# %%
sns.distplot(df['AB'],bins=10,rug=True)

# %%
sns.distplot(df['H'],bins=10,rug=True)

# %%
sns.distplot(df['2B'],bins=10,rug=True)

# %%
sns.distplot(df['3B'],bins=10,rug=True)

# %%
sns.distplot(df['HR'],bins=10,rug=True)

# %%
sns.distplot(df['BB'],bins=10,rug=True)

# %%
sns.distplot(df['SO'],bins=10,rug=True)

# %%
sns.distplot(df['SB'],bins=10,rug=True)

# %%
sns.distplot(df['RA'],bins=10,rug=True)

# %%
sns.distplot(df['ER'],bins=10,rug=True)

# %%
sns.distplot(df['CG'],bins=10,rug=True)

# %%
sns.distplot(df['SHO'],bins=10,rug=True)

# %%
sns.distplot(df['SV'],bins=10,rug=True)

# %%
sns.distplot(df['E'],bins=10,rug=True)

# %%
#bivariate analysis
sns.pairplot(df,height=2.5)

# %%
sns.pairplot(data=df, x_vars=['R', 'AB', 'H', '2B'],y_vars='W',size=2.5, aspect=1, kind='reg')

# %%
sns.pairplot(data=df, x_vars=['3B', 'HR', 'BB', 'SO'],y_vars='W',size=2.5, aspect=1, kind='reg')

# %%
sns.pairplot(data=df, x_vars=['SB', 'RA', 'ER','ERA'], y_vars='W', size=2.5, aspect=1, kind='reg')

# %%
sns.pairplot(data=df, x_vars=['CG', 'SHO', 'SV', 'E'], y_vars='W', size=2.5, aspect=1, kind='reg')

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
sns.heatmap(df.corr())

# %%
print(Features)
# Out:
# ['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA', 'CG', 'SHO', 'SV', 'E']

# %%
#checcking outliers
sns.boxplot(y='R', data=df)

# %%
sns.boxplot(y='AB', data=df)

# %%
sns.boxplot(y='H', data=df)

# %%
sns.boxplot(y='2B', data=df)

# %%
sns.boxplot(y='3B', data=df)

# %%
sns.boxplot(y='HR', data=df)

# %%
sns.boxplot(y='BB', data=df)

# %%
sns.boxplot(y='SO', data=df)

# %%
sns.boxplot(y='SB', data=df)

# %%
sns.boxplot(y='RA', data=df)

# %%
sns.boxplot(y='ER', data=df)

# %%
sns.boxplot(y='ERA', data=df)

# %%
sns.boxplot(y='CG', data=df)

# %%
sns.boxplot(y='SHO', data=df)

# %%
sns.boxplot(y='SV', data=df)

# %%
sns.boxplot(y='E', data=df)

# %%
df1=df

# %%
df1.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df1.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
for x in df1.columns:
    if df1.skew().loc[x]>0.55:
        df1[x]=np.log1p(df1[x])

# %%
df1.skew()
# Out:
# W      0.047089
# R      0.744813
# AB     0.183437
# H      0.628584
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.325962
# SHO   -0.589640
# SV     0.163057
# E      0.632916
# dtype: float64

# %%
from scipy.stats import zscore

# %%
z_score=abs(zscore(df1))
df1.shape
# Out:
# (30, 17)

# %%
df1_final=df1.loc[(z_score<3).all(axis=1)]

# %%
df1_final.shape
# Out:
# (29, 17)

# %%
df1_final.skew()
# Out:
# W      0.119013
# R     -0.388428
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.275681
# SHO   -0.598073
# SV     0.109983
# E      0.586101
# dtype: float64

# %%
sns.boxplot(y='E', data=df1_final)

# %%
X=df1_final.drop(columns='W',axis=1)

# %%
y=df1_final['W']

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
MN=MinMaxScaler()
Sc=StandardScaler()

# %%
X_scaled=MN.fit_transform(X)
X_scaled
# Out:
# array([[0.81303796, 0.71969697, 0.91130142, 0.95522388, 0.80555556,
#         0.3       , 0.04166667, 0.        , 0.66666667, 0.36363636,
#         0.38317757, 0.37619048, 0.44211411, 0.39672304, 0.87099969,
#         0.30753117],
#        [0.6759214 , 0.31060606, 0.13880692, 0.6119403 , 0.86111111,
#         0.43076923, 0.33333333, 0.53394495, 0.28888889, 0.54858934,
#         0.54517134, 0.53809524, 0.44211411, 0.64491666, 0.59464093,
#         0.26326574],
#        [0.53838202, 0.20454545, 0.38762401, 1.        , 0.44444444,
#         0.31538462, 0.82291667, 0.33761468, 0.46666667, 0.36050157,
#         0.33021807, 0.34761905, 1.        , 0.53216451, 0.38186512,
#         0.09989857],
#        [0.28518064, 0.56060606, 0.31277574, 0.35820896, 0.38888889,
#         0.27692308, 0.15104167, 0.4733945 , 0.26666667, 0.55172414,
#         0.51401869, 0.4952381 , 0.83682884, 0.46783549, 0.34838461,
#         0.57305936],
# ...

# %%
(pd.DataFrame(X_scaled)).skew()
# Out:
# 0    -0.388428
# 1     0.169573
# 2     0.738455
# 3    -0.335304
# 4     0.090124
# 5     0.450862
# 6     0.151193
# 7    -0.233815
# 8     0.494966
# 9     0.018155
# 10    0.018461
# 11    0.016693
# 12   -0.275681
# 13   -0.598073
# 14    0.109983
# 15    0.586101
# dtype: float64

# %%
X1_scaled=Sc.fit_transform(X)
X1_scaled
# Out:
# array([[ 0.95271901,  0.83008422,  1.72372599,  1.55653766,  1.01084549,
#         -0.76586314, -1.53635899, -2.72762331,  0.9059529 , -0.66451353,
#         -0.51114812, -0.51138828, -0.24041455, -0.72241314,  1.55481209,
#         -0.43573324],
#        [ 0.35665907, -0.70283074, -0.94984589,  0.20117132,  1.20891656,
#         -0.18138864, -0.49502051,  0.12189552, -0.58531515,  0.15463823,
#          0.23216082,  0.23895226, -0.24041455,  0.31208451,  0.29622875,
#         -0.59810993],
#        [-0.24123892, -1.10025314, -0.08870013,  1.73332457, -0.2766165 ,
#         -0.69710144,  1.25294051, -0.9258657 ,  0.11645805, -0.67839746,
#         -0.75415297, -0.64380131,  1.81571095, -0.15787854, -0.67278738,
#         -1.19738162],
#        [-1.34193161,  0.23395062, -0.34774692, -0.8006212 , -0.47468758,
#         -0.8690057 , -1.14585706, -0.20124579, -0.6730368 ,  0.16852216,
#          0.08921679,  0.04033271,  1.21433279, -0.42600884, -0.82526317,
#          0.53829069],
# ...

# %%
(pd.DataFrame(X1_scaled)).skew()
# Out:
# 0    -0.388428
# 1     0.169573
# 2     0.738455
# 3    -0.335304
# 4     0.090124
# 5     0.450862
# 6     0.151193
# 7    -0.233815
# 8     0.494966
# 9     0.018155
# 10    0.018461
# 11    0.016693
# 12   -0.275681
# 13   -0.598073
# 14    0.109983
# 15    0.586101
# dtype: float64

# %%
X1=pd.DataFrame(data=X_scaled,index=None,columns=X.columns)

# %%
X1.shape
# Out:
# (29, 16)

# %%
X1.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.813038  0.719697  0.911301  0.955224  0.805556  0.300000  0.041667
# 1  0.675921  0.310606  0.138807  0.611940  0.861111  0.430769  0.333333
# 2  0.538382  0.204545  0.387624  1.000000  0.444444  0.315385  0.822917
# 3  0.285181  0.560606  0.312776  0.358209  0.388889  0.276923  0.151042
# 4  0.640781  0.833333  1.000000  0.791045  1.000000  0.392308  0.416667
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0  0.000000  0.666667  0.363636  0.383178  0.376190  0.442114  0.396723
# 1  0.533945  0.288889  0.548589  0.545171  0.538095  0.442114  0.644917
# 2  0.337615  0.466667  0.360502  0.330218  0.347619  1.000000  0.532165
# 3  0.473394  0.266667  0.551724  0.514019  0.495238  0.836829  0.467835
# 4  0.524771  0.433333  0.871473  0.834891  0.809524  0.836829  0.644917
#
#          SV         E
# 0  0.871000  0.307531
# 1  0.594641  0.263266
# 2  0.381865  0.099899
# ...

# %%
y1=pd.DataFrame(y)

# %%
y1.shape
# Out:
# (29, 1)

# %%
y1.head()
# Out:
#     W
# 0  95
# 1  83
# 2  81
# 3  76
# 4  74

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
#from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
#train_X,test_X,train_y,test_y=train_test_split(X,y, random_state=7,test_size=.25)

# %%
#lr=LinearRegression()

# %%
#lr.fit(train_X,train_y)

# %%
#lr.score(train_X,train_y)

# %%
#predict=lr.predict(test_X)

# %%
#r2_scor=r2_score(test_y,predict)
#r2_scor

# %%
#print('MSE=', mean_squared_error(test_y,predict)*100)

# %%
#from sklearn.ensemble import RandomForestRegressor

# %%
#Reg=RandomForestRegressor(max_depth=12,n_estimators=10)

# %%
#Reg.fit(train_X,train_y)

# %%
#Reg.score(train_X,train_y)

# %%
#predict2=Reg.predict(test_X)

# %%
#r2_scor2=r2_score(test_y,predict2)
#r2_scor2

# %%
#print('MSE=', mean_squared_error(test_y,predict2)*100)

# %%
#from sklearn.ensemble import GradientBoostingRegressor

# %%
#GB=GradientBoostingRegressor(random_state=96,n_estimators=200,subsample=0.7)

# %%
#GB.fit(train_X,train_y)

# %%
#predict3=GB.predict(test_X)

# %%
#r2_scor3=r2_score(test_y,predict3)
#r2_scor3

# %%
#print('MSE=', mean_squared_error(test_y,predict3)*100)

# %%
#from sklearn.neighbors import KNeighborsRegressor as KNN

# %%
#kl=KNN(n_neighbors=7)

# %%
#kl.fit(train_X,train_y)

# %%
#predict4=kl.predict(test_X)

# %%
#r2_scor4=r2_score(test_y,predict4)
#r2_scor4

# %%
#print('MSE=', mean_squared_error(test_y,predict4)*100)

# %%
train_X,test_X,train_y,test_y=train_test_split(X1,y1,test_size=.25,random_state=90)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
LR=LinearRegression(fit_intercept=True,
                    normalize=True)
DTR=DecisionTreeRegressor(random_state=7)
KN=KNeighborsRegressor(n_neighbors=7)
SVMR=SVR()
RFR=RandomForestRegressor(n_estimators=12,max_depth=12)
GBR=GradientBoostingRegressor()
ABR=AdaBoostRegressor()

# %%
model_list=[]

# %%
model_list.append(('LinearRegression', LR))

# %%
model_list.append(('DecisionTreeRegressor', DTR))

# %%
model_list.append(('KNeighborsRegressor', KN))

# %%
model_list.append(('SVR', SVMR))

# %%
model_list.append(('RandomForestRegressor', RFR))

# %%
model_list.append(('AdaBoostingRegressor', ABR))

# %%
from sklearn.model_selection import cross_val_score

# %%
Model=[]
MAE=[]
MSA=[]
CS=[]
r2_scor=[]

for name,model in model_list:
    print('**************************************',name,'***********************************************')
    Model.append(name)
    model.fit(train_X,train_y)
    print(model)
    pred=model.predict(test_X)
    print('\n')
    Abs=mean_absolute_error(pred,test_y)
    print('mean absolue error is:',Abs)
    MAE.append(Abs*100)
    print('\n')
    ms=mean_squared_error(pred,test_y)
    print('mean squared error is:',ms)
    MSA.append(ms*100)
    print('\n')
    cs=cross_val_score(model,X=train_X,y=train_y, cv=10,scoring='r2').mean()
    print('cross_val is',cs)
    CS.append(cs*100)
    print('\n')
    r=r2_score(pred,test_y)
    print('r2_scor is :',r)
    r2_scor.append(r*100)
# Out:
# ************************************** LinearRegression ***********************************************
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
#
#
# mean absolue error is: 3.594696494972337
#
#
# mean squared error is: 19.391453392067415
#
#
# cross_val is -9.770866629666372
#
#
# r2_scor is : 0.8138365016911621
# ************************************** DecisionTreeRegressor ***********************************************
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=7, splitter='best')
#
#
# mean absolue error is: 9.625
#
#
# mean squared error is: 109.625
#
#
# cross_val is -5.27399927761361
#
#
# r2_scor is : -0.9774520856820743
# ...

# %%
best_model=pd.DataFrame({'Model': Model,'Mean Absolute Error': MAE,'Mean Squared Error': MSA,
                         'CV_Score':CS,'R2_score':r2_scor})

# %%
best_model
# Out:
#                    Model  Mean Absolute Error  Mean Squared Error    CV_Score  \
# 0       LinearRegression           359.469649         1939.145339 -977.086663
# 1  DecisionTreeRegressor           962.500000        10962.500000 -527.399928
# 2    KNeighborsRegressor           437.500000         2756.887755 -202.529757
# 3                    SVR           598.115359         7589.417580 -317.785347
# 4  RandomForestRegressor           340.625000         1545.746528 -356.430956
# 5   AdaBoostingRegressor           381.923077         1906.580046 -367.889781
#
#        R2_score
# 0     81.383650
# 1    -97.745209
# 2    -87.882476
# 3 -86070.875262
# 4     37.385006
# 5     40.385295

# %% [markdown]
# I will go for Linear Regression as it has good R2 Score.

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters=[{'fit_intercept':['True'],'normalize':['True','False']}]

# %%
grid_search=GridSearchCV(estimator= LR,param_grid= parameters,
                        scoring='r2', cv=10, n_jobs=-1)

# %%
grid_search=grid_search.fit(train_X,train_y)

# %%
score=grid_search.best_score_
score
# Out:
# -9.351551615148782

# %%
grid_search.best_params_
# Out:
# {'fit_intercept': 'True', 'normalize': 'True'}

# %%
best_model.iloc[0:1,:]
# Out:
#               Model  Mean Absolute Error  Mean Squared Error    CV_Score  \
# 0  LinearRegression           359.469649         1939.145339 -977.086663
#
#    R2_score
# 0  81.38365

# %% [markdown]
# Saving this for final model with hyper parameters tunned per Grid Search

# %%
#saving the model
from sklearn.externals import joblib

# %%
joblib.dump(LR,'LRbaseball_joblib')
# Out:
# ['LRbaseball_joblib']
