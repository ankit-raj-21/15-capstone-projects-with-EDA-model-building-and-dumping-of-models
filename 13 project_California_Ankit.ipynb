# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn import datasets

# %%
calihouses = datasets.fetch_california_housing()
calidata = calihouses.data

# %%
headers = calihouses.feature_names
df = pd.DataFrame(calidata, columns=headers)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y=calihouses.target

# %%
y=pd.DataFrame(y)

# %%
y.head()
# Out:
#        0
# 0  4.526
# 1  3.585
# 2  3.521
# 3  3.413
# 4  3.422

# %%
y.shape
# Out:
# (20640, 1)

# %%
df.shape
# Out:
# (20640, 8)

# %%
df['target']=y

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
df.shape
# Out:
# (20640, 9)

# %%
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# target        0
# dtype: int64

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
sns.distplot(df['MedInc'],bins=10,kde=True,rug=True)

# %%
sns.distplot(df['HouseAge'],bins=10,kde=True,rug=True)

# %%
sns.distplot(df['AveRooms'],bins=10,kde=True,rug=True)

# %%
sns.distplot(df['AveBedrms'],bins=10,kde=True,rug=True)

# %%
sns.distplot(df['Population'],bins=10,kde=True,rug=True)

# %%
sns.distplot(df['AveOccup'],bins=10,kde=True,rug=True)

# %%
sns.distplot(df['Latitude'],bins=10,kde=True,rug=True)

# %%
sns.distplot(df['Longitude'],bins=10,kde=True,rug=True)

# %%
#bivariate analysis
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'target'],
#       dtype='object')

# %%
sns.pairplot(data=df, x_vars=['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
       'Latitude', 'Longitude'],y_vars='target',size=4.5, aspect=1, kind='reg')

# %%
fig=fig=plt.figure(figsize=(12,5))
sns.pairplot(data=df, x_vars=['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
       'Latitude', 'Longitude'],y_vars='target',size=None, aspect=1, kind='scatter')

# %%
df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# target      0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude    target
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
fig=fig=plt.figure(figsize=(12,5))
sns.heatmap(df.corr(),annot=True)

# %%
sns.scatterplot(data=df,x='Longitude',y='Latitude')

# %%
df=df.drop(columns='Latitude',axis=1)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Longitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556    -122.23
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842    -122.22
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260    -122.24
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945    -122.25
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467    -122.25
#
#    target
# 0   4.526
# 1   3.585
# 2   3.521
# 3   3.413
# 4   3.422

# %%
df.plot(kind='box',subplots=True,layout=(7,5),figsize=(17,12))
# Out:
# MedInc           AxesSubplot(0.125,0.787927;0.133621x0.0920732)
# HouseAge      AxesSubplot(0.285345,0.787927;0.133621x0.0920732)
# AveRooms       AxesSubplot(0.44569,0.787927;0.133621x0.0920732)
# AveBedrms     AxesSubplot(0.606034,0.787927;0.133621x0.0920732)
# Population    AxesSubplot(0.766379,0.787927;0.133621x0.0920732)
# AveOccup         AxesSubplot(0.125,0.677439;0.133621x0.0920732)
# Longitude     AxesSubplot(0.285345,0.677439;0.133621x0.0920732)
# target         AxesSubplot(0.44569,0.677439;0.133621x0.0920732)
# dtype: object

# %%
from scipy.stats import zscore

# %%
z_score=abs(zscore(df))
df.shape
# Out:
# (20640, 8)

# %%
df=df.loc[(z_score<3).all(axis=1)]

# %%
df.shape
# Out:
# (19794, 8)

# %%
df.plot(kind='box',subplots=True,layout=(7,5),figsize=(17,12))
# Out:
# MedInc           AxesSubplot(0.125,0.787927;0.133621x0.0920732)
# HouseAge      AxesSubplot(0.285345,0.787927;0.133621x0.0920732)
# AveRooms       AxesSubplot(0.44569,0.787927;0.133621x0.0920732)
# AveBedrms     AxesSubplot(0.606034,0.787927;0.133621x0.0920732)
# Population    AxesSubplot(0.766379,0.787927;0.133621x0.0920732)
# AveOccup         AxesSubplot(0.125,0.677439;0.133621x0.0920732)
# Longitude     AxesSubplot(0.285345,0.677439;0.133621x0.0920732)
# target         AxesSubplot(0.44569,0.677439;0.133621x0.0920732)
# dtype: object

# %%
df.skew()
# Out:
# MedInc        0.786048
# HouseAge      0.046496
# AveRooms      0.555865
# AveBedrms     3.913734
# Population    1.346151
# AveOccup      5.789707
# Longitude    -0.292814
# target        0.970197
# dtype: float64

# %%
for x in df.columns:
    if df.skew().loc[x]> 0.55:
        df[x]=np.log1p(df[x])

# %%
df.skew()
# Out:
# MedInc       -0.046003
# HouseAge      0.046496
# AveRooms     -0.303532
# AveBedrms     2.880437
# Population   -1.281355
# AveOccup      0.801586
# Longitude    -0.292814
# target        0.255509
# dtype: float64

# %%
df1=df

# %%
for x in df1.columns:
    if df1.skew().loc[x]> 0.55:
        df1[x]=np.power(df1[x],1/3)

# %%
df1.skew()
# Out:
# MedInc       -0.046003
# HouseAge      0.046496
# AveRooms     -0.303532
# AveBedrms     2.059248
# Population   -1.281355
# AveOccup      0.215018
# Longitude    -0.292814
# target        0.255509
# dtype: float64

# %%
sns.scatterplot(data=df,x='AveBedrms',y='target')

# %%
sns.scatterplot(data=df,x='Population',y='target')

# %%
for x in df1.columns:
    if df1.skew().loc[x]> 0.55:
        df1[x]=np.power(df1[x],1/13)

# %%
df1.skew()
# Out:
# MedInc       -0.046003
# HouseAge      0.046496
# AveRooms     -0.303532
# AveBedrms     1.650915
# Population   -1.281355
# AveOccup      0.215018
# Longitude    -0.292814
# target        0.255509
# dtype: float64

# %%
#AveBedrms is very much skewed so let's drop that column
df1=df1.drop(columns='AveBedrms',axis=1)
df1.head()
# Out:
#      MedInc  HouseAge  AveRooms  Population  AveOccup  Longitude    target
# 0  2.232720      41.0  2.077455    5.777652  1.082509    -122.23  1.709464
# 1  2.230165      21.0  1.979364    7.784057  1.042983    -122.22  1.522790
# 2  2.111110      52.0  2.228738    6.208590  1.101265    -122.24  1.508733
# 3  1.893579      52.0  1.919471    6.326149  1.081899    -122.25  1.484555
# 4  1.578195      52.0  1.985385    6.338594  1.049915    -122.25  1.486592

# %%
for x in df1.columns:
    if df1.skew().loc[x]< -0.55:
        df1[x]=np.power(df1[x],3)

# %%
df1.skew()
# Out:
# MedInc       -0.046003
# HouseAge      0.046496
# AveRooms     -0.303532
# Population   -0.095752
# AveOccup      0.215018
# Longitude    -0.292814
# target        0.255509
# dtype: float64

# %%
X=df1.drop(columns='target',axis=1)
y=df1['target']

# %%
X.shape
# Out:
# (19794, 6)

# %%
y.shape
# Out:
# (19794,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
Sc=StandardScaler()

# %%
X_scaled=Sc.fit_transform(X)
X_scaled
# Out:
# array([[ 2.18526363,  0.96629447,  1.3416884 , -1.74169653, -0.3909433 ,
#         -1.320935  ],
#        [ 2.17765833, -0.64040157,  0.84527043,  1.26750981, -1.15849907,
#         -1.31594443],
#        [ 1.823342  ,  1.84997729,  2.10729235, -1.24026097, -0.02672201,
#         -1.32592557],
#        ...,
#        [-1.50348014, -0.96174078,  0.06631324, -0.25324983, -0.76690501,
#         -0.81688757],
#        [-1.32466552, -0.88140598,  0.1664171 , -0.70703796, -1.13300822,
#         -0.86679325],
#        [-0.82742125, -1.04207558,  0.1062579 ,  0.26546074, -0.29674999,
#         -0.8268687 ]])

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import train_test_split

# %%
train_X,test_X,train_y,test_y=train_test_split(X_scaled,y,test_size=.30,random_state=100)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
LR=LinearRegression()
DTR=DecisionTreeRegressor(random_state=7)
KN=KNeighborsRegressor(n_neighbors=7)
SVMR=SVR()
RFR=RandomForestRegressor(n_estimators=100,max_depth=90)
GBR=GradientBoostingRegressor()
ABR=AdaBoostRegressor()

# %%
model_list=[]

# %%
model_list.append(('LinearRegression', LR))

# %%
model_list.append(('DecisionTreeRegressor', DTR))

# %%
model_list.append(('KNeighborsRegressor', KN))

# %%
model_list.append(('SVR', SVMR))

# %%
model_list.append(('RandomForestRegressor', RFR))

# %%
model_list.append(('AdaBoostingRegressor', ABR))

# %%
from sklearn.model_selection import cross_val_score

# %%
Model=[]
MAE=[]
MSA=[]
CS=[]
r2_scor=[]

for name,model in model_list:
    print('**************************************',name,'***********************************************')
    Model.append(name)
    model.fit(train_X,train_y)
    print(model)
    pred=model.predict(test_X)
    print('\n')
    Abs=mean_absolute_error(pred,test_y)
    print('mean absolue error is:',Abs)
    MAE.append(Abs*100)
    print('\n')
    ms=mean_squared_error(pred,test_y)
    print('mean squared error is:',ms)
    MSA.append(ms*100)
    print('\n')
    cs=cross_val_score(model,X=train_X,y=train_y, cv=10,scoring='r2').mean()
    print('cross_val is',cs)
    CS.append(cs*100)
    print('\n')
    r=r2_score(pred,test_y)
    print('r2_scor is :',r)
    r2_scor.append(r*100)
# Out:
# ************************************** LinearRegression ***********************************************
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#
# mean absolue error is: 0.1742764642650536
#
#
# mean squared error is: 0.050300572205017165
#
#
# cross_val is 0.5634410083495657
#
#
# r2_scor is : 0.28226354982776125
# ************************************** DecisionTreeRegressor ***********************************************
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=7, splitter='best')
#
#
# mean absolue error is: 0.17446703925077373
#
#
# mean squared error is: 0.06268592802987105
#
#
# cross_val is 0.43358197132329257
#
#
# ...

# %%
best_model=pd.DataFrame({'Model': Model,'Mean Absolute Error': MAE,'Mean Squared Error': MSA,
                         'CV_Score':CS,'R2_score':r2_scor})
best_model
# Out:
#                    Model  Mean Absolute Error  Mean Squared Error   CV_Score  \
# 0       LinearRegression            17.427646            5.030057  56.344101
# 1  DecisionTreeRegressor            17.446704            6.268593  43.358197
# 2    KNeighborsRegressor            14.403935            3.761047  67.422048
# 3                    SVR            13.963913            3.510005  69.696717
# 4  RandomForestRegressor            12.950080            3.164322  72.134415
# 5   AdaBoostingRegressor            19.028946            5.589272  51.534190
#
#     R2_score
# 0  28.226355
# 1  49.163428
# 2  55.183011
# 3  60.629060
# 4  63.413754
# 5 -54.172324

# %%
#using gridsearchcv to tune parameters of Random Forest
from sklearn.model_selection import GridSearchCV

# %%
parameters=[{'n_estimators':['warn',10,12,100], 'max_depth':[12,50,90]}]

grid_search=GridSearchCV(estimator= RFR,param_grid= parameters,
                        scoring='r2', cv=10, n_jobs=-1)

# %%
grid_search=grid_search.fit(train_X,train_y)

accuracy_grid= grid_search.best_score_
accuracy_grid
# Out:
# 0.7219170894844469

# %%
grid_search.best_params_
# Out:
# {'max_depth': 50, 'n_estimators': 100}

# %%
#saving the model
from sklearn.externals import joblib
# Out:
# C:\Users\Ankit\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
joblib.dump(RFR,'RFRcalifornia_joblib')
# Out:
# ['RFRcalifornia_joblib']
